# %%
import pandas as pd
from pathlib import Path

# Fils in Folders
path = Path('C:/Users/Admin/OneDrive/Cumulative Test/DataSets')

# List all CSV files in the directory
csv_files = path.glob('*.csv')

# Read and concatenate all CSV files into a single DataFrame
merged_df = pd.concat([pd.read_csv(file, encoding='ISO-8859-1') for file in csv_files], ignore_index=True)

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('merged_data.csv', index=False)

print("CSV files have been successfully merged and saved to 'merged_data.csv'")
# Out:
# CSV files have been successfully merged and saved to 'merged_data.csv'

# %% [markdown]
# # EDA

# %%
print(merged_df.shape)
# Out:
# (390290, 25)

# %%
print(merged_df.columns)
# Out:
# Index(['State Code', 'District Code', 'India/States', 'Division', 'Group',
#        'Class', 'NIC Name', 'Main Workers - Total -  Persons',
#        'Main Workers - Total - Males', 'Main Workers - Total - Females',
#        'Main Workers - Rural -  Persons', 'Main Workers - Rural - Males',
#        'Main Workers - Rural - Females', 'Main Workers - Urban -  Persons',
#        'Main Workers - Urban - Males', 'Main Workers - Urban - Females',
#        'Marginal Workers - Total -  Persons',
#        'Marginal Workers - Total - Males',
#        'Marginal Workers - Total - Females',
#        'Marginal Workers - Rural -  Persons',
#        'Marginal Workers - Rural - Males',
#        'Marginal Workers - Rural - Females',
#        'Marginal Workers - Urban -  Persons',
#        'Marginal Workers - Urban - Males',
#        'Marginal Workers - Urban - Females'],
#       dtype='object')

# %%
merged_df.head(3)
# Out:
#   State Code District Code          India/States Division Group  Class  \
# 0        `07          `000  STATE - NCT OF DELHI      `00  `000  `0000
# 1        `07          `000  STATE - NCT OF DELHI      `01  `000  `0000
# 2        `07          `000  STATE - NCT OF DELHI      `01  `011  `0000
#
#                                             NIC Name  \
# 0                                              Total
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
#
#    Main Workers - Total -  Persons  Main Workers - Total - Males  \
# 0                           828980                        708129
# 1                             1484                          1271
# 2                              169                           151
#
#    Main Workers - Total - Females  ...  Main Workers - Urban - Females  \
# 0                          120851  ...                          117709
# 1                             213  ...                             162
# 2                              18  ...                              16
#
#    Marginal Workers - Total -  Persons  Marginal Workers - Total - Males  \
# 0                                61009                             44743
# 1                                  224                               150
# 2                                   92                                65
#
#    Marginal Workers - Total - Females  Marginal Workers - Rural -  Persons  \
# 0                               16266                                 1969
# 1                                  74                                   23
# 2                                  27                                   14
#
#    Marginal Workers - Rural - Males  Marginal Workers - Rural - Females  \
# 0                              1494                                 475
# 1                                13                                  10
# 2                                12                                   2
#
#    Marginal Workers - Urban -  Persons  Marginal Workers - Urban - Males  \
# 0                                59040                             43249
# 1                                  201                               137
# 2                                   78                                53
#
#    Marginal Workers - Urban - Females
# 0                               15791
# 1                                  64
# 2                                  25
#
# [3 rows x 25 columns]

# %%
merged_df.describe()
# Out:
#        Main Workers - Total -  Persons  Main Workers - Total - Males  \
# count                     3.902900e+05                  3.902900e+05
# mean                      1.492138e+03                  1.193171e+03
# std                       4.568163e+04                  3.773912e+04
# min                       0.000000e+00                  0.000000e+00
# 25%                       6.000000e+00                  6.000000e+00
# 50%                       2.800000e+01                  2.300000e+01
# 75%                       1.880000e+02                  1.450000e+02
# max                       1.561976e+07                  1.280140e+07
#
#        Main Workers - Total - Females  Main Workers - Rural -  Persons  \
# count                    3.902900e+05                     3.902900e+05
# mean                     2.989664e+02                     6.606187e+02
# std                      8.582008e+03                     2.044434e+04
# min                      0.000000e+00                     0.000000e+00
# 25%                      0.000000e+00                     2.000000e+00
# 50%                      3.000000e+00                     1.200000e+01
# 75%                      2.400000e+01                     7.400000e+01
# max                      2.818356e+06                     6.770444e+06
#
#        Main Workers - Rural - Males  Main Workers - Rural - Females  \
# count                  3.902900e+05                    3.902900e+05
# mean                   5.170353e+02                    1.435834e+02
# std                    1.654292e+04                    4.314441e+03
# min                    0.000000e+00                    0.000000e+00
# 25%                    1.000000e+00                    0.000000e+00
# 50%                    8.000000e+00                    0.000000e+00
# 75%                    5.600000e+01                    8.000000e+00
# max                    5.446541e+06                    1.323903e+06
#
#        Main Workers - Urban -  Persons  Main Workers - Urban - Males  \
# count                     3.902900e+05                  3.902900e+05
# mean                      8.315188e+02                  6.761358e+02
# std                       2.586778e+04                  2.167337e+04
# min                       0.000000e+00                  0.000000e+00
# 25%                       2.000000e+00                  1.000000e+00
# 50%                       1.200000e+01                  9.000000e+00
# 75%                       8.600000e+01                  6.700000e+01
# max                       8.849315e+06                  7.354862e+06
#
#        Main Workers - Urban - Females  Marginal Workers - Total -  Persons  \
# count                    3.902900e+05                         3.902900e+05
# mean                     1.553830e+02                         3.642672e+02
# std                      4.531587e+03                         1.176939e+04
# min                      0.000000e+00                         0.000000e+00
# 25%                      0.000000e+00                         0.000000e+00
# 50%                      0.000000e+00                         4.000000e+00
# 75%                      1.200000e+01                         2.800000e+01
# max                      1.494453e+06                         3.834122e+06
#
#        Marginal Workers - Total - Males  Marginal Workers - Total - Females  \
# count                      3.902900e+05                        3.902900e+05
# mean                       1.826322e+02                        1.816350e+02
# std                        5.760568e+03                        6.309691e+03
# min                        0.000000e+00                        0.000000e+00
# 25%                        0.000000e+00                        0.000000e+00
# 50%                        2.000000e+00                        0.000000e+00
# 75%                        1.800000e+01                        6.000000e+00
# max                        1.966750e+06                        1.867372e+06
#
#        Marginal Workers - Rural -  Persons  Marginal Workers - Rural - Males  \
# count                         3.902900e+05                      3.902900e+05
# mean                          2.502286e+02                      1.165241e+02
# std                           8.232264e+03                      3.723073e+03
# min                           0.000000e+00                      0.000000e+00
# 25%                           0.000000e+00                      0.000000e+00
# 50%                           1.000000e+00                      0.000000e+00
# 75%                           1.400000e+01                      8.000000e+00
# max                           2.515182e+06                      1.223824e+06
#
#        Marginal Workers - Rural - Females  \
# count                        3.902900e+05
# mean                         1.337045e+02
# std                          4.748454e+03
# min                          0.000000e+00
# 25%                          0.000000e+00
# 50%                          0.000000e+00
# 75%                          3.000000e+00
# max                          1.291358e+06
#
#        Marginal Workers - Urban -  Persons  Marginal Workers - Urban - Males  \
# count                         3.902900e+05                     390290.000000
# mean                          1.140386e+02                         66.108094
# std                           3.842884e+03                       2132.578995
# min                           0.000000e+00                          0.000000
# 25%                           0.000000e+00                          0.000000
# 50%                           0.000000e+00                          0.000000
# 75%                           9.000000e+00                          6.000000
# max                           1.318940e+06                     742926.000000
#
#        Marginal Workers - Urban - Females
# count                       390290.000000
# mean                            47.930472
# std                           1803.268924
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              2.000000
# max                         576014.000000

# %%
merged_df.isnull().sum()
# Out:
# State Code                             0
# District Code                          0
# India/States                           0
# Division                               0
# Group                                  0
# Class                                  0
# NIC Name                               0
# Main Workers - Total -  Persons        0
# Main Workers - Total - Males           0
# Main Workers - Total - Females         0
# Main Workers - Rural -  Persons        0
# Main Workers - Rural - Males           0
# Main Workers - Rural - Females         0
# Main Workers - Urban -  Persons        0
# Main Workers - Urban - Males           0
# Main Workers - Urban - Females         0
# Marginal Workers - Total -  Persons    0
# Marginal Workers - Total - Males       0
# Marginal Workers - Total - Females     0
# Marginal Workers - Rural -  Persons    0
# Marginal Workers - Rural - Males       0
# Marginal Workers - Rural - Females     0
# Marginal Workers - Urban -  Persons    0
# Marginal Workers - Urban - Males       0
# Marginal Workers - Urban - Females     0
# dtype: int64

# %%
merged_df.columns = merged_df.columns.str.strip().str.lower().str.replace(" ", "-").str.replace("-", "_")

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390290 entries, 0 to 390289
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   state_code                           390290 non-null  object
#  1   district_code                        390290 non-null  object
#  2   india/states                         390290 non-null  object
#  3   division                             390290 non-null  object
#  4   group                                390290 non-null  object
#  5   class                                390290 non-null  object
#  6   nic_name                             390290 non-null  object
#  7   main_workers___total____persons      390290 non-null  int64
#  8   main_workers___total___males         390290 non-null  int64
#  9   main_workers___total___females       390290 non-null  int64
#  10  main_workers___rural____persons      390290 non-null  int64
#  11  main_workers___rural___males         390290 non-null  int64
#  12  main_workers___rural___females       390290 non-null  int64
#  13  main_workers___urban____persons      390290 non-null  int64
#  14  main_workers___urban___males         390290 non-null  int64
#  15  main_workers___urban___females       390290 non-null  int64
#  16  marginal_workers___total____persons  390290 non-null  int64
#  17  marginal_workers___total___males     390290 non-null  int64
#  18  marginal_workers___total___females   390290 non-null  int64
#  19  marginal_workers___rural____persons  390290 non-null  int64
#  20  marginal_workers___rural___males     390290 non-null  int64
#  21  marginal_workers___rural___females   390290 non-null  int64
#  22  marginal_workers___urban____persons  390290 non-null  int64
#  23  marginal_workers___urban___males     390290 non-null  int64
#  24  marginal_workers___urban___females   390290 non-null  int64
# dtypes: int64(18), object(7)
# memory usage: 74.4+ MB

# %% [markdown]
# # Feature Engineering
#
#
# #### -Total workers, -Gender ratio, -Rural/urban ratios

# %% [markdown]
# #### Total workers

# %%
merged_df["total_workers"] = merged_df["main_workers___total____persons"] + merged_df["marginal_workers___total____persons"]

# %%
merged_df["total_workers"] = merged_df["main_workers___total____persons"] + merged_df["marginal_workers___total____persons"]

# %%
merged_df[['main_workers___total____persons','marginal_workers___total____persons','total_workers']].head(3)
# Out:
#    main_workers___total____persons  marginal_workers___total____persons  \
# 0                           828980                                61009
# 1                             1484                                  224
# 2                              169                                   92
#
#    total_workers
# 0         889989
# 1           1708
# 2            261

# %% [markdown]
# #### Gender ratio

# %%
merged_df["female_to_male_ratio"] = merged_df['main_workers___total___females']/merged_df['main_workers___total___males']

# %%
merged_df[['main_workers___total___females','main_workers___total___males','female_to_male_ratio']].head(3)
# Out:
#    main_workers___total___females  main_workers___total___males  \
# 0                          120851                        708129
# 1                             213                          1271
# 2                              18                           151
#
#    female_to_male_ratio
# 0              0.170662
# 1              0.167585
# 2              0.119205

# %% [markdown]
# #### Rural/urban ratios

# %%
merged_df["rural_ratio"] = merged_df['main_workers___rural____persons']/merged_df['main_workers___total____persons']

# %%
merged_df[['main_workers___rural____persons','main_workers___total____persons','rural_ratio']].head(3)
# Out:
#    main_workers___rural____persons  main_workers___total____persons  \
# 0                            20567                           828980
# 1                              179                             1484
# 2                               17                              169
#
#    rural_ratio
# 0     0.024810
# 1     0.120620
# 2     0.100592

# %%
merged_df["urban_ratio"] = merged_df['main_workers___urban____persons'] / merged_df["main_workers___total____persons"]
merged_df[['main_workers___urban____persons','main_workers___total____persons','urban_ratio']].head(3)
# Out:
#    main_workers___urban____persons  main_workers___total____persons  \
# 0                           808413                           828980
# 1                             1305                             1484
# 2                              152                              169
#
#    urban_ratio
# 0     0.975190
# 1     0.879380
# 2     0.899408

# %% [markdown]
# # Grouping and Summarizing
#
# ##  State-wise total workers, Industry division summary

# %% [markdown]
# #### State-wise total workers

# %%
state_group = merged_df.groupby('india/states')[['total_workers', 'main_workers___total____persons']].sum().sort_values("total_workers", ascending=False)
state_group
# Out:
#                                        total_workers  \
# india/states
# STATE - WEST BENGAL                        155631048
# STATE - RAJASTHAN                           90605568
# STATE - TAMIL NADU                          24153768
# District - North Twenty Four Parganas       21469192
# STATE - MAHARASHTRA                         20584792
# ...                                              ...
# District - Kanshiram Nagar                       104
# District - Budaun                                104
# District - Mahe                                   96
# District - Baghpat                                32
# District - Kannauj                                24
#
#                                        main_workers___total____persons
# india/states
# STATE - WEST BENGAL                                          124958072
# STATE - RAJASTHAN                                             72143552
# STATE - TAMIL NADU                                            20551952
# District - North Twenty Four Parganas                         18869416
# STATE - MAHARASHTRA                                           18247192
# ...                                                                ...
# District - Kanshiram Nagar                                          80
# District - Budaun                                                   88
# District - Mahe                                                     96
# District - Baghpat                                                   0
# District - Kannauj                                                   8
#
# [491 rows x 2 columns]

# %% [markdown]
# #### Industry division summary

# %%
division_group = merged_df.groupby('division')[['main_workers___total____persons','marginal_workers___total____persons']].sum()
division_group
# Out:
#           main_workers___total____persons  marginal_workers___total____persons
# division
# `00                             145591588                             35542460
# `01                              18502980                              9807432
# `02                               1120296                               566592
# `03                               1881060                               433848
# `05                               1444104                               102588
# ...                                   ...                                  ...
# `95                               3296604                               452424
# `96                               9113328                              1688892
# `97                               6074064                              1828296
# `98                                 10080                                 2832
# `99                              19778148                             21974772
#
# [89 rows x 2 columns]

# %% [markdown]
# # Geo-Visualization Preparation

# %% [markdown]
# ####  Save aggregated data for mapping

# %%
state_summary = merged_df.groupby("india/states").agg({
    'main_workers___total____persons':'sum',
    'marginal_workers___total____persons': 'sum'
}).reset_index()

# %%
state_summary
# Out:
#               india/states  main_workers___total____persons  \
# 0          District - Agra                            11600
# 1     District - Ahmadabad                          1734520
# 2    District - Ahmadnagar                           610832
# 3        District - Aizawl                           857664
# 4         District - Ajmer                          4014448
# ..                     ...                              ...
# 486     STATE - TAMIL NADU                         20551952
# 487        STATE - TRIPURA                          1006480
# 488  STATE - UTTAR PRADESH                           564960
# 489    STATE - UTTARAKHAND                           204400
# 490    STATE - WEST BENGAL                        124958072
#
#      marginal_workers___total____persons
# 0                                   3104
# 1                                 161616
# 2                                  92296
# 3                                 134216
# 4                                 857576
# ..                                   ...
# 486                              3601816
# 487                               330008
# 488                               422456
# 489                                75248
# 490                             30672976
#
# [491 rows x 3 columns]

# %%
state_summary.columns = ["state", "main_workers", "marginal_workers"]
state_summary.to_csv("state_workforce_summary.csv", index=False)

# %% [markdown]
# # NLP for Industry Grouping

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
# Example: Cluster industries based on NIC Name
tfidf = TfidfVectorizer(stop_words='english')
X = tfidf.fit_transform(merged_df['nic_name'])

kmeans = KMeans(n_clusters=10, random_state=42)
merged_df['industry_cluster'] = kmeans.fit_predict(X)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Admin\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
merged_df.head(3)
# Out:
#   state_code district_code          india/states division group  class  \
# 0        `07          `000  STATE - NCT OF DELHI      `00  `000  `0000
# 1        `07          `000  STATE - NCT OF DELHI      `01  `000  `0000
# 2        `07          `000  STATE - NCT OF DELHI      `01  `011  `0000
#
#                                             nic_name  \
# 0                                              Total
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
#
#    main_workers___total____persons  main_workers___total___males  \
# 0                           828980                        708129
# 1                             1484                          1271
# 2                              169                           151
#
#    main_workers___total___females  ...  marginal_workers___rural___males  \
# 0                          120851  ...                              1494
# 1                             213  ...                                13
# 2                              18  ...                                12
#
#    marginal_workers___rural___females  marginal_workers___urban____persons  \
# 0                                 475                                59040
# 1                                  10                                  201
# 2                                   2                                   78
#
#    marginal_workers___urban___males  marginal_workers___urban___females  \
# 0                             43249                               15791
# 1                               137                                  64
# 2                                53                                  25
#
#    total_workers  female_to_male_ratio  rural_ratio  urban_ratio  \
# 0         889989              0.170662     0.024810     0.975190
# 1           1708              0.167585     0.120620     0.879380
# 2            261              0.119205     0.100592     0.899408
#
#    industry_cluster
# 0                 4
# 1                 4
# 2                 4
#
# [3 rows x 30 columns]

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top_states = state_group.head(10).reset_index()
sns.barplot(x="india/states", y="total_workers", data=top_states)
plt.xticks(rotation=45)
plt.title("Top 10 States by Total Workers")
plt.show()

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from shapely.geometry import Point

# === 1. Load the GeoJSON (India State Boundaries) ===
map_df = gpd.read_file("gadm41_IND_1.json")
map_df = map_df.rename(columns={"NAME_1": "state"})

# === 2. Your State-wise Data ===
# Replace this with your actual data
state_summary = pd.DataFrame({
    "state": ["Maharashtra", "Uttar Pradesh", "AndhraPradesh", "Karnataka", "Gujarat", "Bihar"],
    "main_workers": [5000000, 6000000, 4500000, 3000000, 3500000, 4000000]
})

# === 3. Merge GeoDataFrame with Data ===
merged_map_df = map_df.merge(state_summary, on="state", how="left")

# === 4. Assign a Unique Color to Each State ===
# Use colormap with enough variety
num_states = len(merged_map_df)
colors = plt.cm.get_cmap('tab20b', num_states)
merged_map_df['color'] = [colors(i % 20) for i in range(num_states)]

# === 5. Create the Plot ===
fig, ax = plt.subplots(figsize=(16, 12))

# Plot each state with its assigned color
merged_map_df.plot(
    color=merged_map_df['color'],
    edgecolor='black',
    linewidth=0.6,
    ax=ax
)

# === 6. Add Worker Count Labels to Each State ===
for idx, row in merged_map_df.iterrows():
    if pd.notnull(row['main_workers']):
        # Place text at the center of the polygon
        centroid = row['geometry'].centroid
        ax.text(
            centroid.x,
            centroid.y,
            f"{int(row['main_workers']):,}",  # format with commas
            horizontalalignment='center',
            verticalalignment='center',
            fontsize=9,
            fontweight='bold',
            color='white',
            bbox=dict(facecolor='black', alpha=0.5, boxstyle='round,pad=0.2')
        )

# === 7. Final Touches ===
ax.set_title("Main Workers by State in India", fontsize=18, weight='bold')
ax.axis("off")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21040\3286199252.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab20b', num_states)

# %%
map_df
# Out:
#        GID_1 GID_0 COUNTRY                state  \
# 0    IND.1_1   IND   India    AndamanandNicobar
# 1    IND.2_1   IND   India        AndhraPradesh
# 2    IND.3_1   IND   India     ArunachalPradesh
# 3    Z07.3_1   Z07   India     ArunachalPradesh
# 4    IND.4_1   IND   India                Assam
# 5    IND.5_1   IND   India                Bihar
# 6    IND.6_1   IND   India           Chandigarh
# 7    IND.7_1   IND   India         Chhattisgarh
# 8    IND.8_1   IND   India  DadraandNagarHaveli
# 9    IND.9_1   IND   India          DamanandDiu
# 10  IND.10_1   IND   India                  Goa
# 11  IND.11_1   IND   India              Gujarat
# 12  IND.12_1   IND   India              Haryana
# 13  IND.13_1   IND   India      HimachalPradesh
# 14  Z04.13_1   Z04   India      HimachalPradesh
# 15  Z09.13_1   Z09   India      HimachalPradesh
# 16  Z01.14_1   Z01   India      JammuandKashmir
# 17  IND.15_1   IND   India            Jharkhand
# 18  IND.16_1   IND   India            Karnataka
# 19  IND.17_1   IND   India               Kerala
# 20  IND.18_1   IND   India          Lakshadweep
# 21  IND.19_1   IND   India        MadhyaPradesh
# 22  IND.20_1   IND   India          Maharashtra
# 23  IND.21_1   IND   India              Manipur
# 24  IND.22_1   IND   India            Meghalaya
# 25  IND.23_1   IND   India              Mizoram
# 26  IND.24_1   IND   India             Nagaland
# 27  IND.25_1   IND   India           NCTofDelhi
# 28  IND.26_1   IND   India               Odisha
# 29  IND.27_1   IND   India           Puducherry
# 30  IND.28_1   IND   India               Punjab
# 31  IND.29_1   IND   India            Rajasthan
# 32  IND.30_1   IND   India               Sikkim
# 33  IND.31_1   IND   India            TamilNadu
# 34  IND.32_1   IND   India            Telangana
# 35  IND.33_1   IND   India              Tripura
# 36  IND.34_1   IND   India         UttarPradesh
# 37  IND.35_1   IND   India          Uttarakhand
# 38  Z05.35_1   Z05   India          Uttarakhand
# 39  Z09.35_1   Z09   India          Uttarakhand
# 40  IND.36_1   IND   India           WestBengal
#
#                            VARNAME_1 NL_NAME_1         TYPE_1       ENGTYPE_1  \
# 0      Andaman&NicobarIslands|Andama        NA  UnionTerritor  UnionTerritory
# 1                                 NA        NA          State           State
# 2        AgencedelaFrontièreduNord-E        NA          State           State
# 3        AgencedelaFrontièreduNord-E        NA          State           State
# 4                                 NA        NA          State           State
# 5                                 NA        NA          State           State
# 6                                 NA        NA  UnionTerritor  UnionTerritory
# 7                                 NA        NA          State           State
# 8        DAdraetNagarHaveli|DadraeNa        NA  UnionTerritor  UnionTerritory
# 9                                 NA        NA  UnionTerritor  UnionTerritory
# 10                               Gôa        NA          State           State
# 11       Goudjerate|Gujerat|Gujerate        NA          State           State
# 12                                NA        NA          State           State
# 13                                NA        NA  UnionTerritor  UnionTerritory
# 14                                NA        NA  UnionTerritor  UnionTerritory
# 15                                NA        NA  UnionTerritor  UnionTerritory
# 16                                NA        NA          State           State
# 17                         Vananchal        NA          State           State
# 18                     Maisur|Mysore        NA          State           State
# 19                                NA        NA          State           State
# 20   ÍlesLaquedives|Laccadive|Minico        NA  UnionTerritor  UnionTerritory
# 21                                NA        NA          State           State
# 22                                NA        NA          State           State
# 23                                NA        NA          State           State
# 24                                NA        NA          State           State
# 25                                NA        NA          State           State
# 26                                NA        NA          State           State
# 27                                NA        NA  UnionTerritor  UnionTerritory
# 28                                NA        NA          State           State
# 29  Pondicherry|Puduchcheri|Pondiché        NA  UnionTerritor  UnionTerritory
# 30                                NA        NA          State           State
# 31        GreaterRajasthan|Rajputana        NA          State           State
# 32                                NA        NA          State           State
# 33                   Madras|Tamilnad        NA          State           State
# 34                                NA        NA          State           State
# 35                                NA        NA          State           State
# 36                   UnitedProvinces        NA          State           State
# 37                       Uttarakhand        NA          State           State
# 38                       Uttarakhand        NA          State           State
# 39                       Uttarakhand        NA          State           State
# 40   Bangla|BengalaOccidentale|Benga        NA          State           State
#
#    CC_1 HASC_1  ISO_1                                           geometry
# 0    NA  IN.AN     NA  MULTIPOLYGON (((93.7908 6.8514, 93.7872 6.8478...
# 1    NA  IN.AP  IN-AP  MULTIPOLYGON (((78.7395 13.0455, 78.7255 13.05...
# 2    NA  IN.AR  IN-AR  MULTIPOLYGON (((95.3683 27.1074, 95.3737 27.10...
# 3    NA  IN.AR     NA  MULTIPOLYGON (((94.1912 27.4963, 94.1869 27.49...
# 4    NA  IN.AS  IN-AS  MULTIPOLYGON (((92.7545 24.5011, 92.7436 24.47...
# 5    NA  IN.BR  IN-BR  MULTIPOLYGON (((86.0431 24.7774, 86.0344 24.77...
# 6    NA  IN.CH  IN-CH  MULTIPOLYGON (((76.8282 30.7638, 76.8227 30.74...
# 7    NA  IN.CT  IN-CT  MULTIPOLYGON (((81.8878 18.6316, 81.8884 18.62...
# 8    NA  IN.DN  IN-DN  MULTIPOLYGON (((73.0551 20.3252, 73.0667 20.32...
# 9    NA  IN.DD     NA  MULTIPOLYGON (((72.8218 20.371, 72.8279 20.387...
# 10   NA  IN.GA  IN-GA  MULTIPOLYGON (((74.273 14.9741, 74.2701 14.966...
# 11   NA  IN.GJ  IN-GJ  MULTIPOLYGON (((72.946 20.2934, 72.9414 20.292...
# 12   NA  IN.HR  IN-HR  MULTIPOLYGON (((76.2768 28.1728, 76.2782 28.16...
# 13   NA  IN.HP  IN-HP  MULTIPOLYGON (((77.5356 30.4091, 77.5258 30.41...
# 14   NA  IN.HP     NA  MULTIPOLYGON (((78.6513 32.0923, 78.6524 32.08...
# 15   NA  IN.HP     NA  MULTIPOLYGON (((78.7778 31.4014, 78.808 31.392...
# 16   NA  IN.JK     NA  MULTIPOLYGON (((75.0716 32.483, 75.0614 32.482...
# 17   NA  IN.JH  IN-JH  MULTIPOLYGON (((85.2107 22.0432, 85.1835 22.05...
# 18   NA  IN.KA  IN-KA  MULTIPOLYGON (((76.081 11.9607, 76.0728 11.961...
# 19   NA  IN.KL  IN-KL  MULTIPOLYGON (((77.2515 8.571, 77.2597 8.5491,...
# 20   NA  IN.LD  IN-LD  MULTIPOLYGON (((73.0107 8.2799, 73.0129 8.2788...
# 21   NA  IN.MP  IN-MP  MULTIPOLYGON (((75.948 21.393, 75.9165 21.3898...
# 22   NA  IN.MH  IN-MH  MULTIPOLYGON (((73.9713 15.6873, 73.9657 15.69...
# 23   NA  IN.MN  IN-MN  MULTIPOLYGON (((93.7444 24.0012, 93.74 23.9992...
# 24   NA  IN.ML  IN-ML  MULTIPOLYGON (((91.3684 25.1708, 91.3637 25.17...
# 25   NA  IN.MZ  IN-MZ  MULTIPOLYGON (((93.194 24.0563, 93.1983 24.052...
# 26   NA  IN.NL  IN-NL  MULTIPOLYGON (((93.458 25.3301, 93.4619 25.336...
# 27   NA  IN.DL     NA  MULTIPOLYGON (((77.3377 28.509, 77.3345 28.511...
# 28   NA  IN.OR  IN-OR  MULTIPOLYGON (((81.9045 17.9735, 81.8993 17.96...
# 29   NA  IN.PY  IN-PY  MULTIPOLYGON (((79.8543 10.9743, 79.8529 10.96...
# 30   NA  IN.PB  IN-PB  MULTIPOLYGON (((75.9031 29.7463, 75.8972 29.75...
# 31   NA  IN.RJ  IN-RJ  MULTIPOLYGON (((74.282 23.1064, 74.2881 23.118...
# 32   NA  IN.SK  IN-SK  MULTIPOLYGON (((88.9194 27.3246, 88.9197 27.32...
# 33   NA  IN.TN  IN-TN  MULTIPOLYGON (((77.556 8.0771, 77.5537 8.0768,...
# 34   NA  IN.TG  IN-TG  MULTIPOLYGON (((79.2075 16.2307, 79.192 16.222...
# 35   NA  IN.TR  IN-TR  MULTIPOLYGON (((91.3896 23.1773, 91.3886 23.17...
# 36   NA  IN.UP  IN-UP  MULTIPOLYGON (((83.2842 24.0646, 83.2775 24.05...
# 37   NA  IN.UT  IN-UT  MULTIPOLYGON (((79.5658 28.8495, 79.5572 28.84...
# 38   NA  IN.UT     NA  MULTIPOLYGON (((80.0879 30.7907, 80.1031 30.77...
# 39   NA  IN.UT     NA  MULTIPOLYGON (((78.9069 31.2592, 78.9131 31.26...
# 40   NA  IN.WB  IN-WB  MULTIPOLYGON (((88.5414 21.6356, 88.5478 21.63...
